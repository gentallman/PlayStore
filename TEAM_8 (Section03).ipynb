# %% [markdown]
# ## TEAM 008 (Section 003)

# %% [markdown]
# ### Table of Contents
#
# 1. <a href="#1.-Descriptive-Statistics">Descriptive Statistics</a>
# 2. <a href="#2.-Exploratory-Data-Analysis">Exploratory Data Analysis</a>
# 3. <a href="#3.-Data-Cleaning">Data Cleaning</a>
# 4. <a href="#4.-Data-Analysis">Data Analysis</a>

# %% [markdown]
#  Data Source : https://github.com/gentallman/PlayStore/blob/main/playstore_games_final.csv

# %% [markdown]
# ### Packages, which are used in this project.

# %%
import pandas 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Descriptive Statistics

# %% [markdown]
# ### Load and Display the Dataset

# %%
play = pandas.read_csv(r"playstore_games_final.csv",encoding='latin1')
play.head()
# Out:
#                             title  total_ratings  install_million  avg_rating  \
# 0  Garena Free Fire- World Series       86273129              500           4
# 1                  Clash of Clans       55766763              500           4
# 2                    PUBG MOBILE        37276732              500           4
# 3                  Subway Surfers       35665901             1000           4
# 4                Candy Crush Saga       31367945             1000           4
#
#    growth_30days  growth_60days  Category  5_star_rating  4_star_rating  \
# 0            2.1            6.9    Action       63546766        4949507
# 1            0.3            1.0  Strategy       43346128        5404966
# 2            1.8            3.6    Action       28339753        2164478
# 3            0.5            1.0    Arcade       27138572        3366600
# 4            0.9            1.6    Casual       23837448        4176798
#
#    3_star_rating  2_star_rating  1_star_rating  price   paid
# 0        3158756        2122183       12495915    0.0  False
# 1        2276203         971321        3768141    0.0  False
# 2        1253185         809821        4709492    0.0  False
# 3        1622695         814890        2723142    0.0  False
# 4        1534041         486005        1333650    0.0  False

# %% [markdown]
# ### Generate descriptive statistics.such as mean, min, max, standard deviation, etc.

# %%
play.describe()
# Out:
#        total_ratings  install_million   avg_rating  growth_30days  \
# count   1.565000e+03      1565.000000  1565.000000    1553.000000
# mean    1.129571e+06        32.566134     3.908626     346.624791
# std     3.594120e+06        68.141854     0.290442    6337.718460
# min     3.299300e+04         1.000000     2.000000       0.000000
# 25%     2.053390e+05        10.000000     4.000000       0.100000
# 50%     4.552820e+05        10.000000     4.000000       0.500000
# 75%     9.133570e+05        50.000000     4.000000       1.800000
# max     8.627313e+07      1000.000000     4.000000  227105.700000
#
#        growth_60days  5_star_rating  4_star_rating  3_star_rating  \
# count    1556.000000   1.565000e+03   1.565000e+03   1.565000e+03
# mean      125.610347   8.092804e+05   1.226447e+05   6.026576e+04
# std      2344.141866   2.661120e+06   3.159710e+05   1.563826e+05
# min         0.000000   1.397500e+04   2.471000e+03   7.180000e+02
# 25%         0.275000   1.400660e+05   2.258900e+04   1.074700e+04
# 50%         1.000000   3.115810e+05   5.349900e+04   2.675600e+04
# 75%         3.525000   6.488790e+05   1.063500e+05   5.366900e+04
# max     69441.400000   6.354677e+07   5.404966e+06   3.158756e+06
#
#        2_star_rating  1_star_rating        price
# count   1.565000e+03   1.565000e+03  1565.000000
# mean    2.888931e+04   1.084879e+05     0.010185
# std     8.538533e+04   4.281821e+05     0.213092
# min     3.780000e+02   6.170000e+02     0.000000
# 25%     4.859000e+03   1.460200e+04     0.000000
# 50%     1.158500e+04   3.650800e+04     0.000000
# 75%     2.452200e+04   8.592400e+04     0.000000
# max     2.122183e+06   1.249592e+07     7.490000

# %% [markdown]
# ### Display number of rows/columns.

# %%
play.shape
# Out:
# (1565, 14)

# %% [markdown]
# ### Extract column name

# %%
play.columns
# Out:
# Index(['title', 'total_ratings', 'install_million', 'avg_rating',
#        'growth_30days', 'growth_60days', 'Category', '5_star_rating',
#        '4_star_rating', '3_star_rating', '2_star_rating', '1_star_rating',
#        'price', 'paid'],
#       dtype='object')

# %% [markdown]
# ### Check the number of nulls

# %%
play.isnull().sum()
# Out:
# title               0
# total_ratings       0
# install_million     0
# avg_rating          0
# growth_30days      12
# growth_60days       9
# Category            0
# 5_star_rating       0
# 4_star_rating       0
# 3_star_rating       0
# 2_star_rating       0
# 1_star_rating       0
# price               0
# paid                0
# dtype: int64

# %%
null_value = play.isnull().sum()
null_value.index
# Out:
# Index(['title', 'total_ratings', 'install_million', 'avg_rating',
#        'growth_30days', 'growth_60days', 'Category', '5_star_rating',
#        '4_star_rating', '3_star_rating', '2_star_rating', '1_star_rating',
#        'price', 'paid'],
#       dtype='object')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.bar(null_value.index,null_value,linewidth=1)
plt.xticks(rotation=90)
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Check data and datatype of each column

# %%
play.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            1565 non-null   object
#  1   total_ratings    1565 non-null   int64
#  2   install_million  1565 non-null   int64
#  3   avg_rating       1565 non-null   int64
#  4   growth_30days    1553 non-null   float64
#  5   growth_60days    1556 non-null   float64
#  6   Category         1565 non-null   object
#  7   5_star_rating    1565 non-null   int64
#  8   4_star_rating    1565 non-null   int64
#  9   3_star_rating    1565 non-null   int64
#  10  2_star_rating    1565 non-null   int64
#  11  1_star_rating    1565 non-null   int64
#  12  price            1565 non-null   float64
#  13  paid             1565 non-null   bool
# dtypes: bool(1), float64(3), int64(8), object(2)
# memory usage: 160.6+ KB

# %% [markdown]
# ### Count the values in columns.

# %%
play['Category'].value_counts()
# Out:
# Action         100
# Casual         100
# Racing         100
# Arcade          97
# Sports          97
# Simulation      96
# Strategy        95
# Educational     95
# Adventure       95
# RolePlaying     94
# Board           93
# Puzzle          92
# Casino          92
# Music           91
# Word            77
# Trivia          76
# Card            75
# Name: Category, dtype: int64

# %% [markdown]
# ### Show Top 10

# %%
play['title'].value_counts().head(10)
# Out:
# Bubble Shooter                              4
# The Simpsonsâ¢: Tapped Out                 2
# Sudoku                                      2
# Real Racing 3                               2
# Garena Free Fire- World Series              1
# Soccer Kicks (Football)                     1
# Think                                       1
# Word Search Sea: Unscramble words           1
# Governor of Poker 2 - OFFLINE POKER GAME    1
# Zombie Defense                              1
# Name: title, dtype: int64

# %% [markdown]
# ### Numerical variable

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
ax = plt.hist(play.install_million, bins=20)
plt.xlabel("Installtion (Million)")
plt.ylabel("Absolute Frequency")
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
ax = sns.boxplot(x=play['total_ratings'],orient="h").set(xlabel="Total Ratings", title="Numeric variable 'Total Ratings'");

# %% [markdown]
# ### Is there any outliers present in dataset ?

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
play.boxplot(column=["total_ratings",	"install_million",	"avg_rating",	"growth_30days",	"growth_60days",		"5_star_rating",	"4_star_rating",	"3_star_rating",	"2_star_rating",	"1_star_rating",	"price"])
plt.xlabel("Category of Games", size = 15)
plt.ylabel("No. of Installs (Million)", size = 15)
plt.xticks(rotation=90)
plt.title("Outliers", size = 18)
plt.savefig("outliers.png")
plt.show()

# %% [markdown]
# ### No. of Distinct Values with column name and its data type

# %%
feature_names=list(play.columns)
pandas.DataFrame([[f, play[f].dtype, play[f].nunique()] for f in feature_names], 
              columns=['feature', 'type', 'distinct values'])
# Out:
#             feature     type  distinct values
# 0             title   object             1559
# 1     total_ratings    int64             1564
# 2   install_million    int64                7
# 3        avg_rating    int64                3
# 4     growth_30days  float64              182
# 5     growth_60days  float64              200
# 6          Category   object               17
# 7     5_star_rating    int64             1562
# 8     4_star_rating    int64             1559
# 9     3_star_rating    int64             1546
# 10    2_star_rating    int64             1526
# 11    1_star_rating    int64             1555
# 12            price  float64                5
# 13             paid     bool                2

# %% [markdown]
# [<a href="#TEAM-008-(Section-003)">Back to Top</a>]

# %% [markdown]
# ## 2. Exploratory Data Analysis

# %% [markdown]
# ### Which is the most installed game genre?

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.barplot(x = play['install_million'], y = play['Category'])
plt.ylabel("Category of Games", size = 15)
plt.xlabel("No. of Installs (Million)", size = 15)
plt.title("Highest installed Games' Categories", size = 18)
plt.show()
plt.savefig("barplot.png")

# %% [markdown]
# ### Which genre caught highest growth after 60 days of launch ?

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.lineplot(y = play['growth_60days'], x = play['Category'])
plt.xticks(rotation=90)
plt.xlabel("Game Genre", size = 15)
plt.ylabel("Growth After 60 Days of Launch", size = 15)
plt.title("Growth after 60 Days of game release", size = 18)
plt.show()
plt.savefig("lineplot.png")

# %% [markdown]
# ### Count the average ratings given to games on Play Store.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
ax = sns.countplot(play['avg_rating'])
for p in ax.patches:
        ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))
plt.xlabel("Average Rating", size = 15)
plt.ylabel("Count", size = 15)
plt.title("Average Rating Count of Games", size = 18)
plt.savefig("countplot.png")

# %% [markdown]
# [<a href="#TEAM-008-(Section-003)">Back to Top</a>]

# %% [markdown]
# ## 3. Data Cleaning

# %% [markdown]
# ## Detecting the missing values

# %%
## Before Cleaning the dataset
play.isnull().sum()
# Out:
# title               0
# total_ratings       0
# install_million     0
# avg_rating          0
# growth_30days      12
# growth_60days       9
# Category            0
# 5_star_rating       0
# 4_star_rating       0
# 3_star_rating       0
# 2_star_rating       0
# 1_star_rating       0
# price               0
# paid                0
# dtype: int64

# %% [markdown]
# ## Displaying columns with its amount of missing values

# %%
def missing_cols(df):
    total = 0
    for col in df.columns:
        missing_vals = df[col].isnull().sum()
        total += missing_vals
        if missing_vals != 0:
            print(f"{col} => {df[col].isnull().sum()}")
    
    if total == 0:
        print("no missing values left")
            
missing_cols(play)
# Out:
# growth_30days => 12
# growth_60days => 9

# %% [markdown]
# ## Printing out columns with missing values with its %

# %%
def perc_missing(df):
    for col in df.columns:
        pct = df[col].isna().mean() * 100
        if (pct != 0):
            print('{} => {}%'.format(col, round(pct, 2)))
    
perc_missing(play)
# Out:
# growth_30days => 0.77%
# growth_60days => 0.58%

# %% [markdown]
# ## Visulaizing the missing value through HeatMap

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(play.isnull(), yticklabels=False, cmap='viridis', cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Imputing - filling in null values with '0'

# %%
play.fillna({'growth_30days':0}, inplace=True)

# %%
play.fillna({'growth_60days':0}, inplace=True)

# %%
## After Cleaning the dataset
play.isnull().sum()
# Out:
# title              0
# total_ratings      0
# install_million    0
# avg_rating         0
# growth_30days      0
# growth_60days      0
# Category           0
# 5_star_rating      0
# 4_star_rating      0
# 3_star_rating      0
# 2_star_rating      0
# 1_star_rating      0
# price              0
# paid               0
# dtype: int64

# %% [markdown]
# [<a href="#TEAM-008-(Section-003)">Back to Top</a>]

# %% [markdown]
# ## 4. Data Analysis

# %% [markdown]
# ### Show the rating(1-5) for different games group.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.lineplot(y = play['1_star_rating'], x = play['Category'],err_style="bars", ci=68) #blue
sns.lineplot(y = play['2_star_rating'], x = play['Category'],err_style="bars", ci=68) #yellow
sns.lineplot(y = play['3_star_rating'], x = play['Category'],err_style="bars", ci=68) #green
sns.lineplot(y = play['4_star_rating'], x = play['Category'],err_style="bars", ci=68) #red
sns.lineplot(y = play['5_star_rating'], x = play['Category'],err_style="bars", ci=68) #purple
plt.xticks(rotation=90)
plt.xlabel("Game Genre", size = 15)
plt.ylabel("Rating from 5(*)", size = 15)
plt.title("Whole ratings with games", size = 18)
plt.show()
warnings.filterwarnings('ignore')

# %% [markdown]
# ### How many users prefer to download paid/free games from Google Play Store?

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
play.paid.value_counts(normalize=True).plot.pie(autopct='%.2f%%', colors = ['lightgreen', 'red'])
plt.title('How many Users like paid games?')
plt.legend(title = "Paid:")
plt.title('How many Users like paid games?', size = 18)
plt.show()
plt.savefig("pieplot.png")

# %% [markdown]
# ### Which genres of games are highly rated with paid/free norm?

# %%
fig, ax= plt.subplots()
fig.set_size_inches(11.7, 8.27)
ax= sns.barplot(data=play,hue="paid",x="total_ratings", y="Category")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1,1))
plt.title('Highly rated paid/free games with their category?', size = 18)
warnings.filterwarnings('ignore')

# %% [markdown]
# ### How is relation between installation count and highest rating of game based on paid criteria ?

# %%
fig, ax= plt.subplots()
fig.set_size_inches(7.7, 4.27)
ax = sns.lineplot(data = play,x = "install_million", y = "5_star_rating", hue = "paid", style = "paid")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1,1))
plt.xlabel("No.of Installs (Million)", size = 15)
plt.ylabel("5 Star Ratings", size = 15)
plt.title('Games that are installed with hightes ratings', size = 12)
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Which type of game are installed and rated mostly at same time ?

# %%
fig, ax= plt.subplots()
fig.set_size_inches(11.7, 8.27)
ax = sns.scatterplot(x = play['install_million'], y = play['total_ratings'], hue=play['Category'] , alpha = 0.8)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1,1))
plt.xlabel("No.of Installs (Million)", size = 15)
plt.ylabel("Total Ratings (10 million)", size = 15)
plt.title('Games that are installed and rated both', size = 18)
warnings.filterwarnings('ignore')

# %% [markdown]
# [<a href="#TEAM-008-(Section-003)">Back to Top</a>]
